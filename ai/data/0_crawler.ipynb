# %%
import requests
import os
from PIL import Image
import imagehash
import glob

# %%
flower_label = {
                'buquet' : 0,
                'rose' : 0,             # 장미
                'empty1' : 1,
                'tulip' : 2,            # 튤립
                'carnation' : 3,
                'empty2' : 4,        # 카네이션
                'lily' : 5,             # 백합
                'lisianthus' : 6,       # 리시안셔스
                'small_chrysanthemum' : 7,    # 소국
                'pompom_blooms' : 8,    # 퐁퐁국화
                'sunflower': 9,         # 해바라기
                'gerbera' : 10,          # 거베라
                'alstroemeria' : 11,     # 알스트로메리아
                'hydrangea' : 12,       # 수국
                'peony' : 13,           # 작약
                'stock' : 14,           # 스톡
                'freesia' : 15,         # 프리지아
                'ranunculus' : 16,      # 라넌큘러스
                'empty3' : 17,
                'butterfly':18,  # 라넌큘러스 버터플라이
                'cala': 19,               # 칼라 꽃
                'snapdragon' : 20,        # 금어초
                }

# %%
url = 'https://openapi.naver.com/v1/search/image'
header = {
    'X-Naver-Client-Id': 'iwPIgOh0e7a1fgeRVg3y',
    'X-Naver-Client-Secret' : 'rRjO7XI0eu'
}

# flowers = ['해바라기 한 송이', '거베라', '튤립 한 송이', '카네이션 한 송이', '리시안셔스 한 송이', '스프레이 장미 한 송이', '작약 한 송이', '라넌큘러스 한 송이', '프리지아 한 송이', '소국', '국화 한 송이', '백합 한 송이', '알스트로메리아']
# dirs = ['sunflower', 'gubera', 'tulip', 'canation', 'risiansus', 'spray_rose', 'jacyak', 'lanunculase', 'prizia', 'small_guka', 'guka', 'backhap', 'alstromeria']
flowers = ['프리지아 꽃', '프리지아 한 송이']
dirs = ['freesia', 'freesia']

for i in range(len(flowers)):
    
    q = flowers[i]
    directory = dirs[i]
    
    if not os.path.isdir(f'./0_flower_data/{directory}'):
        os.makedirs(f'./0_flower_data/{directory}')
    
    for s in [1, 101, 201, 301, 401, 501]:
        print(f'{q} : {s}번째')
        params = {
            'query' : q,
            'display' : 100,
            'start' : s
        }

        req = requests.get(url=url, params=params, headers=header).json()

        items = req['items']

        cnt = int(os.listdir(f'./0_flower_data/{directory}/')[-1][:-4][-4:])+1 if os.listdir(f'./0_flower_data/{directory}/') else 0

        for item in items:
            try:
                img_url = item['link']
                response = requests.get(img_url)
                fn = str(cnt).rjust(4,'0')
                with open(f'./0_flower_data/{directory}/{directory}_{fn}.jpg', 'wb') as f:
                    f.write(response.content)
            except:
                print('여긴 안 되네양')
            cnt += 1
# Out:
# 프리지아 꽃 : 1번째
# 여긴 안 되네양
# 프리지아 꽃 : 101번째
# 프리지아 꽃 : 201번째
# 프리지아 꽃 : 301번째
# 프리지아 꽃 : 401번째
# 프리지아 꽃 : 501번째
# 프리지아 한 송이 : 1번째
# 프리지아 한 송이 : 101번째
# 프리지아 한 송이 : 201번째
# 프리지아 한 송이 : 301번째
# 프리지아 한 송이 : 401번째
# 프리지아 한 송이 : 501번째

# %%
flower = 'freesia'

hash_dict = {}
x = []
for f in os.listdir(f'./0_flower_data/{flower}'):

    image_files = glob.glob(f"./0_flower_data/{flower}/{f}")  # 이미지 파일 경로 수정

    for image_path in image_files:
        try:
            with Image.open(image_path) as img:
                img_hash = imagehash.phash(img)
                if img_hash not in hash_dict:
                    hash_dict[img_hash] = image_path
                else:
                    print(f"중복 이미지 발견: {image_path}")
                    x.append(image_path)
        except:
            x.append(image_path)

for i in x:
    print('이미지 삭제 : ', i)
    os.remove(i)
# Out:
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0200.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0201.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0445.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0555.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0600.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0601.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0602.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0603.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0604.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0605.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0606.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0609.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0610.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0611.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0613.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0615.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0616.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0617.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0623.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0626.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0627.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0640.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0646.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0648.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0649.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0652.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0659.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0661.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0663.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0666.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0667.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0668.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0682.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0687.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0705.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0711.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0714.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0725.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0738.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0785.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0800.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0801.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0802.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0806.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0843.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0848.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0850.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0852.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0853.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0854.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0857.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0861.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0864.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0866.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0869.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_0890.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_1021.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_1077.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_1101.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_1113.jpg
# 중복 이미지 발견: ./0_flower_data/freesia/freesia_1171.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0083.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0104.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0108.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0119.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0163.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0194.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0200.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0201.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0216.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0307.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0310.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0351.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0358.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0409.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0445.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0555.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0588.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0599.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0600.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0601.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0602.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0603.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0604.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0605.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0606.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0609.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0610.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0611.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0613.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0615.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0616.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0617.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0623.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0626.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0627.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0640.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0646.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0648.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0649.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0652.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0659.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0661.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0663.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0666.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0667.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0668.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0682.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0687.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0705.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0711.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0714.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0725.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0738.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0743.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0767.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0785.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0800.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0801.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0802.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0806.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0810.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0819.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0830.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0843.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0848.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0850.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0852.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0853.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0854.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0857.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0861.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0864.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0866.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0869.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_0890.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1021.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1077.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1091.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1101.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1113.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1146.jpg
# 이미지 삭제 :  ./0_flower_data/freesia/freesia_1171.jpg

# %% [markdown]
# ### RGB로 변경 및 ICC 프로파일 제거

# %%
from PIL import Image

flower = 'freesia'

for f in os.listdir(f'./0_flower_data/{flower}'):
    img_path = f'./0_flower_data/{flower}/{f}'
    try:
        with Image.open(img_path) as img:
            img = img.convert('RGB')
            img.save(img_path, 'JPEG', icc_profile=None)  # ICC 프로파일 제거
    except:
        print('이 사진 순 나쁜 사진이에요! : ', f)
        os.remove(f'./0_flower_data/{flower}/{f}')

# %% [markdown]
# ### 이미지 파일 부재시, 라벨 파일도 함께 삭제

# %%
for CLS in ['train', 'test']:
    img_list = os.listdir(f'./5_total_data/{CLS}/images')
    for f in os.listdir(f'./5_total_data/{CLS}/labels/'):
        f_jpg = f[:-4]+'.jpg'
        if f_jpg not in img_list:
            print(f)

# %%
from PIL import Image

def fix_image(image_path, output_path):
    try:
        # 이미지 파일을 엽니다.
        img = Image.open(image_path)

        # 이미지를 새로운 파일에 저장합니다.
        img.save(output_path, "JPEG")
        print(f"이미지가 성공적으로 저장되었습니다: {output_path}")
    except IOError:
        os.remove(image_path)
        print(f"이미지 처리 중 오류가 발생했습니다: {image_path}")

# 이미지 파일 경로
f_list = os.listdir('./3_one_time_data/test/images/')


for f in f_list:
    image_path = f"./3_one_time_data/test/images/{f}"
    output_path = f"./3_one_time_data/test/images/{f}"
    fix_image(image_path, output_path)
# Out:
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0002.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0004.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0005.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0010.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0026.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0048.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0058.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0090.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0151.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0155.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0158.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0163.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0222.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0227.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0231.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0253.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0257.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0264.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0265.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0295.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0300.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0304.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0314.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0345.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0360.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0365.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0380.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0386.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0391.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0397.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0404.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0422.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0430.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0435.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0444.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0457.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0459.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0462.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0475.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0477.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0487.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0501.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0503.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0509.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0521.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0533.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0557.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0558.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0580.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0583.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0584.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0587.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0609.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0623.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0643.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0666.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0675.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0703.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0710.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0713.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0750.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0790.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0800.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0808.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0814.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0817.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0863.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0869.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0878.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0894.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0911.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0915.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0938.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0956.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0972.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_0975.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1012.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1038.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1051.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1074.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1101.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1104.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1105.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1112.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1126.jpg
# 이미지가 성공적으로 저장되었습니다: ./3_one_time_data/test/images/hydrangea_1170.jpg
